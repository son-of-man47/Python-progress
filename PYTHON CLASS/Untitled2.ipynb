# %%
import pandas as pd
import numpy as np

# %%
file = "C:/Users/IROANYA/Documents/DATA ANALYSIS FILES/finnstats/Airlinedata.csv"

# %%
dt = pd.read_csv(file)

# %%
df = dt.copy()

# %%
df.head()
# Out:
#    Unnamed: 0  Month  DayOfWeek  FlightDate Reporting_Airline Origin Dest  \
# 0           1      3          5  2003-03-28                UA    LAX  JFK
# 1           2     11          4  2018-11-29                AS    LAX  JFK
# 2           3      8          5  2015-08-28                UA    LAX  JFK
# 3           4      4          7  2003-04-20                DL    LAX  JFK
# 4           5     11          3  2005-11-30                UA    LAX  JFK
#
#    CRSDepTime  CRSArrTime  DepTime  ArrTime  ArrDelay  ArrDelayMinutes  \
# 0        2210         615     2209      617         2                2
# 1        1045        1912     1049     1851       -21                0
# 2         805        1634      757     1620       -14                0
# 3        2205         619     2212      616        -3                0
# 4         840        1653      836     1640       -13                0
#
#    CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Month', 'DayOfWeek', 'FlightDate', 'Reporting_Airline',
#        'Origin', 'Dest', 'CRSDepTime', 'CRSArrTime', 'DepTime', 'ArrTime',
#        'ArrDelay', 'ArrDelayMinutes', 'CarrierDelay', 'WeatherDelay',
#        'NASDelay', 'SecurityDelay', 'LateAircraftDelay', 'DepDelay',
#        'DepDelayMinutes', 'DivDistance', 'DivArrDelay'],
#       dtype='object')

# %%
df.shape
# Out:
# (2855, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2855 entries, 0 to 2854
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2855 non-null   int64
#  1   Month              2855 non-null   int64
#  2   DayOfWeek          2855 non-null   int64
#  3   FlightDate         2855 non-null   object
#  4   Reporting_Airline  2855 non-null   object
#  5   Origin             2855 non-null   object
#  6   Dest               2855 non-null   object
#  7   CRSDepTime         2855 non-null   int64
#  8   CRSArrTime         2855 non-null   int64
#  9   DepTime            2855 non-null   int64
#  10  ArrTime            2855 non-null   int64
#  11  ArrDelay           2855 non-null   int64
#  12  ArrDelayMinutes    2855 non-null   int64
#  13  CarrierDelay       369 non-null    float64
#  14  WeatherDelay       369 non-null    float64
#  15  NASDelay           369 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0              0
# Month                   0
# DayOfWeek               0
# FlightDate              0
# Reporting_Airline       0
# Origin                  0
# Dest                    0
# CRSDepTime              0
# CRSArrTime              0
# DepTime                 0
# ArrTime                 0
# ArrDelay                0
# ArrDelayMinutes         0
# CarrierDelay         2486
# WeatherDelay         2486
# NASDelay             2486
# SecurityDelay        2486
# LateAircraftDelay    2486
# DepDelay                0
# DepDelayMinutes         0
# DivDistance          2855
# DivArrDelay          2855
# dtype: int64

# %%
df = df.drop(["DivDistance", "DivArrDelay", "Month", "DayOfWeek"], axis = 1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'FlightDate', 'Reporting_Airline', 'Origin', 'Dest',
#        'CRSDepTime', 'CRSArrTime', 'DepTime', 'ArrTime', 'ArrDelay',
#        'ArrDelayMinutes', 'CarrierDelay', 'WeatherDelay', 'NASDelay',
#        'SecurityDelay', 'LateAircraftDelay', 'DepDelay', 'DepDelayMinutes'],
#       dtype='object')

# %%
pd.set_option("display.max.columns", None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2855 entries, 0 to 2854
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2855 non-null   int64
#  1   FlightDate         2855 non-null   object
#  2   Reporting_Airline  2855 non-null   object
#  3   Origin             2855 non-null   object
#  4   Dest               2855 non-null   object
#  5   CRSDepTime         2855 non-null   int64
#  6   CRSArrTime         2855 non-null   int64
#  7   DepTime            2855 non-null   int64
#  8   ArrTime            2855 non-null   int64
#  9   ArrDelay           2855 non-null   int64
#  10  ArrDelayMinutes    2855 non-null   int64
#  11  CarrierDelay       369 non-null    float64
#  12  WeatherDelay       369 non-null    float64
#  13  NASDelay           369 non-null    float64
#  14  SecurityDelay      369 non-null    float64
#  15  LateAircraftDelay  369 non-null    float64
# ...

# %%
def moving(x, y):
    col = df.pop(x)
    df.insert(y, x, col)

# %%
moving("DepDelayMinutes", 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2855 entries, 0 to 2854
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2855 non-null   int64
#  1   FlightDate         2855 non-null   object
#  2   Reporting_Airline  2855 non-null   object
#  3   Origin             2855 non-null   object
#  4   Dest               2855 non-null   object
#  5   CRSDepTime         2855 non-null   int64
#  6   CRSArrTime         2855 non-null   int64
#  7   DepTime            2855 non-null   int64
#  8   ArrTime            2855 non-null   int64
#  9   ArrDelay           2855 non-null   int64
#  10  ArrDelayMinutes    2855 non-null   int64
#  11  CarrierDelay       369 non-null    float64
#  12  DepDelayMinutes    2855 non-null   int64
#  13  WeatherDelay       369 non-null    float64
#  14  NASDelay           369 non-null    float64
#  15  SecurityDelay      369 non-null    float64
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  FlightDate Reporting_Airline Origin Dest  CRSDepTime  \
# 0           1  2003-03-28                UA    LAX  JFK        2210
# 1           2  2018-11-29                AS    LAX  JFK        1045
# 2           3  2015-08-28                UA    LAX  JFK         805
# 3           4  2003-04-20                DL    LAX  JFK        2205
# 4           5  2005-11-30                UA    LAX  JFK         840
#
#    CRSArrTime  DepTime  ArrTime  ArrDelay  ArrDelayMinutes  CarrierDelay  \
# 0         615     2209      617         2                2           NaN
# 1        1912     1049     1851       -21                0           NaN
# 2        1634      757     1620       -14                0           NaN
# 3         619     2212      616        -3                0           NaN
# 4        1653      836     1640       -13                0           NaN
#
#    DepDelayMinutes  WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay  \
# ...

# %%
df = df.drop(["DepDelayMinutes", "ArrDelayMinutes"], axis  = 1)

# %%
df.head()
# Out:
#    Unnamed: 0  FlightDate Reporting_Airline Origin Dest  CRSDepTime  \
# 0           1  2003-03-28                UA    LAX  JFK        2210
# 1           2  2018-11-29                AS    LAX  JFK        1045
# 2           3  2015-08-28                UA    LAX  JFK         805
# 3           4  2003-04-20                DL    LAX  JFK        2205
# 4           5  2005-11-30                UA    LAX  JFK         840
#
#    CRSArrTime  DepTime  ArrTime  ArrDelay  CarrierDelay  WeatherDelay  \
# 0         615     2209      617         2           NaN           NaN
# 1        1912     1049     1851       -21           NaN           NaN
# 2        1634      757     1620       -14           NaN           NaN
# 3         619     2212      616        -3           NaN           NaN
# 4        1653      836     1640       -13           NaN           NaN
#
#    NASDelay  SecurityDelay  LateAircraftDelay  DepDelay
# 0       NaN            NaN                NaN        -1
# ...

# %%
a = np.array(df["CRSArrTime"])

n_t = []
for i in a:
    for d in len(i):
        c = d[:2] + ":" + d[2:]
        n_t.append(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12500/2947600826.py in <module>
#       3 n_t = []
#       4 for i in a:
# ----> 5     for d in len(i):
#       6         c = d[:2] + ":" + d[2:]
#       7         n_t.append(d)
#
# TypeError: object of type 'numpy.int64' has no len()
